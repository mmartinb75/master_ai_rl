# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np

class MultiPeriodNewsvendorEnv(gym.Env):
    """
    Multi-period newsvendor problem with vendor lead time and lost sales.
    """
    metadata = {"render_modes": ["human"]}

    def __init__(self, lead_time=5, episode_length=40, mu=100, price=50, cost=25, holding=0.5, penalty=5, max_order=300):
        super().__init__()
        self.lead_time = lead_time
        self.episode_length = episode_length
        self.mu = mu  # Mean of Poisson demand
        self.price = price
        self.cost = cost
        self.holding = holding
        self.penalty = penalty
        self.max_order = max_order

        self.action_space = spaces.Box(low=0.0, high=1.0, shape=(1,), dtype=np.float32)
        self.observation_space = spaces.Box(low=0, high=np.inf, shape=(lead_time + 1,), dtype=np.float32)

        self.reset()

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.t = 0
        self.pipeline = [0] * self.lead_time
        self.inventory = 0
        self.state = np.array([self.inventory] + self.pipeline, dtype=np.float32)
        return self.state, {}

    def step(self, action):
        order_qty = int(action[0] * self.max_order)
        demand = np.random.poisson(self.mu)

        # Receive oldest order
        self.inventory += self.pipeline.pop(0)
        self.pipeline.append(order_qty)

        sold = min(self.inventory, demand)
        lost_sales = max(0, demand - self.inventory)
        leftover = max(0, self.inventory - demand)

        revenue = self.price * sold
        cost = self.cost * order_qty
        holding_cost = self.holding * leftover
        penalty_cost = self.penalty * lost_sales

        reward = revenue - cost - holding_cost - penalty_cost
        self.inventory = leftover

        self.state = np.array([self.inventory] + self.pipeline, dtype=np.float32)
        self.t += 1
        terminated = self.t >= self.episode_length

        return self.state, reward, terminated, False, {}

    def render(self):
        print(f"Time: {self.t}, Inventory: {self.inventory}, Pipeline: {self.pipeline}")

# %%
# Guardar el modelo entrenado

# Evaluar el modelo
env = MultiPeriodNewsvendorEnv()
obs, _ = env.reset()
total_reward = 0
for _ in range(env.episode_length):
    action= env.action_space.sample()
    print(action*300)
    obs, reward, done, _, _ = env.step(action)
    total_reward += reward
    env.render()
    if done:
        break

print(f"Total reward: {total_reward}")
# Out:
# [291.09695]
# Time: 1, Inventory: 0, Pipeline: [0, 0, 0, 0, 291]
# [277.9776]
# Time: 2, Inventory: 0, Pipeline: [0, 0, 0, 291, 277]
# [11.105144]
# Time: 3, Inventory: 0, Pipeline: [0, 0, 291, 277, 11]
# [151.51865]
# Time: 4, Inventory: 0, Pipeline: [0, 291, 277, 11, 151]
# [248.24957]
# Time: 5, Inventory: 0, Pipeline: [291, 277, 11, 151, 248]
# [264.42224]
# Time: 6, Inventory: 192, Pipeline: [277, 11, 151, 248, 264]
# [69.916565]
# Time: 7, Inventory: 365, Pipeline: [11, 151, 248, 264, 69]
# [46.619904]
# Time: 8, Inventory: 288, Pipeline: [151, 248, 264, 69, 46]
# [125.67666]
# Time: 9, Inventory: 351, Pipeline: [248, 264, 69, 46, 125]
# [236.43262]
# Time: 10, Inventory: 493, Pipeline: [264, 69, 46, 125, 236]
# [261.69342]
# Time: 11, Inventory: 647, Pipeline: [69, 46, 125, 236, 261]
# [4.663822]
# Time: 12, Inventory: 627, Pipeline: [46, 125, 236, 261, 4]
# [143.28151]
# Time: 13, Inventory: 586, Pipeline: [125, 236, 261, 4, 143]
# [39.12287]
# Time: 14, Inventory: 619, Pipeline: [236, 261, 4, 143, 39]
# [186.2598]
# Time: 15, Inventory: 759, Pipeline: [261, 4, 143, 39, 186]
# [211.93327]
# Time: 16, Inventory: 919, Pipeline: [4, 143, 39, 186, 211]
# [139.04225]
# Time: 17, Inventory: 822, Pipeline: [143, 39, 186, 211, 139]
# [63.23937]
# Time: 18, Inventory: 870, Pipeline: [39, 186, 211, 139, 63]
# [66.73248]
# Time: 19, Inventory: 799, Pipeline: [186, 211, 139, 63, 66]
# [283.5766]
# Time: 20, Inventory: 895, Pipeline: [211, 139, 63, 66, 283]
# [244.23376]
# Time: 21, Inventory: 1021, Pipeline: [139, 63, 66, 283, 244]
# [145.16864]
# Time: 22, Inventory: 1050, Pipeline: [63, 66, 283, 244, 145]
# [222.4779]
# Time: 23, Inventory: 1012, Pipeline: [66, 283, 244, 145, 222]
# [10.291036]
# Time: 24, Inventory: 986, Pipeline: [283, 244, 145, 222, 10]
# [4.9552984]
# Time: 25, Inventory: 1179, Pipeline: [244, 145, 222, 10, 4]
# [260.52438]
# Time: 26, Inventory: 1322, Pipeline: [145, 222, 10, 4, 260]
# [170.17189]
# Time: 27, Inventory: 1379, Pipeline: [222, 10, 4, 260, 170]
# [64.90671]
# Time: 28, Inventory: 1513, Pipeline: [10, 4, 260, 170, 64]
# [212.90536]
# Time: 29, Inventory: 1434, Pipeline: [4, 260, 170, 64, 212]
# [20.006544]
# Time: 30, Inventory: 1327, Pipeline: [260, 170, 64, 212, 20]
# [90.21062]
# Time: 31, Inventory: 1477, Pipeline: [170, 64, 212, 20, 90]
# [157.00848]
# Time: 32, Inventory: 1556, Pipeline: [64, 212, 20, 90, 157]
# [184.30238]
# Time: 33, Inventory: 1520, Pipeline: [212, 20, 90, 157, 184]
# [99.21329]
# Time: 34, Inventory: 1633, Pipeline: [20, 90, 157, 184, 99]
# [6.1471963]
# Time: 35, Inventory: 1533, Pipeline: [90, 157, 184, 99, 6]
# [244.3695]
# Time: 36, Inventory: 1532, Pipeline: [157, 184, 99, 6, 244]
# [254.32632]
# Time: 37, Inventory: 1582, Pipeline: [184, 99, 6, 244, 254]
# [297.87872]
# Time: 38, Inventory: 1652, Pipeline: [99, 6, 244, 254, 297]
# [69.76419]
# Time: 39, Inventory: 1643, Pipeline: [6, 244, 254, 297, 69]
# [51.731]
# Time: 40, Inventory: 1542, Pipeline: [244, 254, 297, 69, 51]
# Total reward: 3917.5

# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env import DummyVecEnv



# Crear y validar el entorno
env = MultiPeriodNewsvendorEnv()
check_env(env, warn=True)

# Envolver el entorno para entrenamiento
vec_env = DummyVecEnv([lambda: env])

# Inicializar el agente PPO
model = PPO("MlpPolicy", vec_env, verbose=1, learning_rate=1e-4, n_steps=2048, batch_size=64, gamma=0.99)

# Entrenar el modelo
model.learn(total_timesteps=100_000)
# Out:
# /Users/mmartin/opt/anaconda3/envs/rl_course/lib/python3.12/site-packages/stable_baselines3/common/env_checker.py:462: UserWarning: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) cf. https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   warnings.warn(
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 7099 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3748          |
# |    iterations           | 2             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00012248501 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -9.42e-06     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.8e+08       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000979     |
# |    std                  | 0.999         |
# |    value_loss           | 4e+08         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3334         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0002480346 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 7.88e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.27e+08     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0021      |
# |    std                  | 0.998        |
# |    value_loss           | 3.74e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3165          |
# |    iterations           | 4             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00014046449 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.000147      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.93e+08      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00123      |
# |    std                  | 0.997         |
# |    value_loss           | 3.64e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3069          |
# |    iterations           | 5             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00010498645 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.000151      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.94e+08      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000954     |
# |    std                  | 0.996         |
# |    value_loss           | 3.45e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2991         |
# |    iterations           | 6            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 3.512719e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.000141     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.86e+08     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000456    |
# |    std                  | 0.996        |
# |    value_loss           | 4.02e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2957          |
# |    iterations           | 7             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 4.5024964e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.000113      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.77e+08      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000456     |
# |    std                  | 0.995         |
# |    value_loss           | 3.68e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2927         |
# |    iterations           | 8            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 1.132043e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.000156     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.94e+08     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000168    |
# |    std                  | 0.995        |
# |    value_loss           | 4.18e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2907          |
# |    iterations           | 9             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 2.2312015e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.000118      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.34e+08      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.00027      |
# |    std                  | 0.994         |
# |    value_loss           | 4e+08         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2890          |
# |    iterations           | 10            |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 4.6622008e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.000108      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.12e+08      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000431     |
# |    std                  | 0.993         |
# |    value_loss           | 3.67e+08      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2874        |
# |    iterations           | 11          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 4.63959e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.000105    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.06e+08    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.000465   |
# |    std                  | 0.992       |
# |    value_loss           | 3.87e+08    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2858         |
# |    iterations           | 12           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 6.519025e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 6.21e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.49e+08     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000101    |
# |    std                  | 0.991        |
# |    value_loss           | 4.27e+08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2842         |
# |    iterations           | 13           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 4.008235e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 8.27e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.89e+08     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000427    |
# |    std                  | 0.991        |
# |    value_loss           | 3.3e+08      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2819          |
# |    iterations           | 14            |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 2.7322298e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 4.95e-05      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.75e+08      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000375     |
# |    std                  | 0.99          |
# |    value_loss           | 4.02e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2811          |
# |    iterations           | 15            |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 1.8948456e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 5.91e-05      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.62e+08      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000246     |
# |    std                  | 0.989         |
# |    value_loss           | 4.11e+08      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2808        |
# |    iterations           | 16          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 7.27023e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 3.76e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.08e+08    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.000694   |
# |    std                  | 0.989       |
# |    value_loss           | 3.36e+08    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2806          |
# |    iterations           | 17            |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 1.6762846e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 3.28e-05      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.87e+08      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000217     |
# |    std                  | 0.988         |
# |    value_loss           | 3.85e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2795         |
# |    iterations           | 18           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 2.370737e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 3.4e-05      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.72e+08     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000275    |
# |    std                  | 0.988        |
# |    value_loss           | 3.7e+08      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2792          |
# |    iterations           | 19            |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 2.0662177e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 3.37e-05      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.18e+08      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000243     |
# |    std                  | 0.988         |
# |    value_loss           | 3.85e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2791         |
# |    iterations           | 20           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 4.051157e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 2.53e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.73e+08     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000412    |
# |    std                  | 0.987        |
# |    value_loss           | 3.7e+08      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2790          |
# |    iterations           | 21            |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 1.3850775e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 2.57e-05      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.88e+08      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000239     |
# |    std                  | 0.986         |
# |    value_loss           | 3.28e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2790         |
# |    iterations           | 22           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 5.874608e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 2.14e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.06e+08     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000114    |
# |    std                  | 0.986        |
# |    value_loss           | 4.2e+08      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2789          |
# |    iterations           | 23            |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 2.1916116e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 2.41e-05      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.39e+08      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000276     |
# |    std                  | 0.985         |
# |    value_loss           | 2.93e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2788          |
# |    iterations           | 24            |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 1.5593832e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 1.92e-05      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.99e+08      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000217     |
# |    std                  | 0.985         |
# |    value_loss           | 3.76e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2787          |
# |    iterations           | 25            |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 1.2155215e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 1.77e-05      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.05e+08      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -5.66e-05     |
# |    std                  | 0.985         |
# |    value_loss           | 3.92e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2786          |
# |    iterations           | 26            |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 6.1379105e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 1.51e-05      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.73e+08      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000104     |
# |    std                  | 0.985         |
# |    value_loss           | 3.93e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2781          |
# |    iterations           | 27            |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 1.5773636e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 1.26e-05      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.63e+08      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000215     |
# |    std                  | 0.985         |
# |    value_loss           | 4.25e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2781          |
# |    iterations           | 28            |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 3.5858247e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 1.1e-05       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.62e+08      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -9.76e-05     |
# |    std                  | 0.984         |
# |    value_loss           | 3.36e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2778          |
# |    iterations           | 29            |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 1.5620724e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 8.29e-06      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.7e+08       |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000206     |
# |    std                  | 0.984         |
# |    value_loss           | 3.9e+08       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2775         |
# |    iterations           | 30           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 7.281109e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 6.74e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.84e+08     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000168    |
# |    std                  | 0.983        |
# |    value_loss           | 3.29e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2765          |
# |    iterations           | 31            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 1.2323551e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 6.08e-06      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.6e+08       |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000163     |
# |    std                  | 0.983         |
# |    value_loss           | 3.51e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2751          |
# |    iterations           | 32            |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 2.5997288e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 5.3e-06       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2e+08         |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -7.11e-05     |
# |    std                  | 0.983         |
# |    value_loss           | 3.79e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2727          |
# |    iterations           | 33            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 5.2726537e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 4.41e-06      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.21e+08      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000106     |
# |    std                  | 0.983         |
# |    value_loss           | 3.87e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2712          |
# |    iterations           | 34            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 3.5330537e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 3.99e-06      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.67e+08      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.000394     |
# |    std                  | 0.983         |
# |    value_loss           | 3.35e+08      |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 2700           |
# |    iterations           | 35             |
# |    time_elapsed         | 26             |
# |    total_timesteps      | 71680          |
# | train/                  |                |
# |    approx_kl            | 1.28079555e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.4           |
# |    explained_variance   | 2.86e-06       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.98e+08       |
# |    n_updates            | 340            |
# |    policy_gradient_loss | -0.000182      |
# |    std                  | 0.982          |
# |    value_loss           | 3.55e+08       |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2689         |
# |    iterations           | 36           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 1.591153e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 1.79e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.75e+08     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000205    |
# |    std                  | 0.982        |
# |    value_loss           | 3.38e+08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2675         |
# |    iterations           | 37           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 4.362315e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 1.67e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.63e+08     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000103    |
# |    std                  | 0.981        |
# |    value_loss           | 3.54e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2663          |
# |    iterations           | 38            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 3.6162091e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 2.15e-06      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.37e+08      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -8.79e-05     |
# |    std                  | 0.981         |
# |    value_loss           | 3.33e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2640         |
# |    iterations           | 39           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 1.266427e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 2.15e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.38e+08     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000173    |
# |    std                  | 0.981        |
# |    value_loss           | 3.24e+08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2630         |
# |    iterations           | 40           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 4.544476e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 1.61e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.7e+08      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000112    |
# |    std                  | 0.981        |
# |    value_loss           | 3.19e+08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2616         |
# |    iterations           | 41           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 4.287722e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 1.43e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.48e+08     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -8.13e-05    |
# |    std                  | 0.981        |
# |    value_loss           | 3.43e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2591          |
# |    iterations           | 42            |
# |    time_elapsed         | 33            |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 1.3341982e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 1.55e-06      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.95e+08      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000199     |
# |    std                  | 0.98          |
# |    value_loss           | 3.37e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2581          |
# |    iterations           | 43            |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 5.5117125e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 1.13e-06      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.69e+08      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000125     |
# |    std                  | 0.98          |
# |    value_loss           | 3.39e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2580          |
# |    iterations           | 44            |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 1.1461962e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 1.07e-06      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.41e+08      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -5.52e-05     |
# |    std                  | 0.979         |
# |    value_loss           | 3.21e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2567         |
# |    iterations           | 45           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 4.292786e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 1.07e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.43e+08     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -9.58e-05    |
# |    std                  | 0.979        |
# |    value_loss           | 3.62e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2565          |
# |    iterations           | 46            |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 6.4108463e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 9.54e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.82e+08      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -9.42e-05     |
# |    std                  | 0.979         |
# |    value_loss           | 3.63e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2567          |
# |    iterations           | 47            |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 2.7184433e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 8.94e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.46e+08      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -9.01e-05     |
# |    std                  | 0.978         |
# |    value_loss           | 3.28e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2569         |
# |    iterations           | 48           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 2.127752e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 7.75e-07     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.8e+08      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -8.65e-05    |
# |    std                  | 0.978        |
# |    value_loss           | 3.49e+08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2572         |
# |    iterations           | 49           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 8.939009e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 5.96e-07     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.55e+08     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000142    |
# |    std                  | 0.977        |
# |    value_loss           | 3.24e+08     |
# ------------------------------------------

# %%
# Guardar el modelo entrenado
model.save("ppo_newsvendor")

# Evaluar el modelo
obs, _ = env.reset()
total_reward = 0
for _ in range(env.episode_length):
    action, _ = model.predict(obs)
    print(action*300)
    obs, reward, done, _, _ = env.step(action)
    total_reward += reward
    env.render()
    if done:
        break

print(f"Total reward: {total_reward}")
# Out:
# [0.]
# Time: 1, Inventory: 0, Pipeline: [0, 0, 0, 0, 0]
# [141.79575]
# Time: 2, Inventory: 0, Pipeline: [0, 0, 0, 0, 141]
# [260.26855]
# Time: 3, Inventory: 0, Pipeline: [0, 0, 0, 141, 260]
# [83.57681]
# Time: 4, Inventory: 0, Pipeline: [0, 0, 141, 260, 83]
# [0.]
# Time: 5, Inventory: 0, Pipeline: [0, 141, 260, 83, 0]
# [34.459476]
# Time: 6, Inventory: 0, Pipeline: [141, 260, 83, 0, 34]
# [300.]
# Time: 7, Inventory: 35, Pipeline: [260, 83, 0, 34, 300]
# [0.]
# Time: 8, Inventory: 187, Pipeline: [83, 0, 34, 300, 0]
# [0.]
# Time: 9, Inventory: 164, Pipeline: [0, 34, 300, 0, 0]
# [175.71413]
# Time: 10, Inventory: 56, Pipeline: [34, 300, 0, 0, 175]
# [0.]
# Time: 11, Inventory: 0, Pipeline: [300, 0, 0, 175, 0]
# [0.]
# Time: 12, Inventory: 205, Pipeline: [0, 0, 175, 0, 0]
# [154.95032]
# Time: 13, Inventory: 124, Pipeline: [0, 175, 0, 0, 154]
# [0.]
# Time: 14, Inventory: 14, Pipeline: [175, 0, 0, 154, 0]
# [221.62448]
# Time: 15, Inventory: 108, Pipeline: [0, 0, 154, 0, 221]
# [46.113102]
# Time: 16, Inventory: 9, Pipeline: [0, 154, 0, 221, 46]
# [44.980427]
# Time: 17, Inventory: 0, Pipeline: [154, 0, 221, 46, 44]
# [0.]
# Time: 18, Inventory: 60, Pipeline: [0, 221, 46, 44, 0]
# [0.]
# Time: 19, Inventory: 0, Pipeline: [221, 46, 44, 0, 0]
# [300.]
# Time: 20, Inventory: 109, Pipeline: [46, 44, 0, 0, 300]
# [0.]
# Time: 21, Inventory: 55, Pipeline: [44, 0, 0, 300, 0]
# [0.]
# Time: 22, Inventory: 19, Pipeline: [0, 0, 300, 0, 0]
# [28.134052]
# Time: 23, Inventory: 0, Pipeline: [0, 300, 0, 0, 28]
# [222.81082]
# Time: 24, Inventory: 0, Pipeline: [300, 0, 0, 28, 222]
# [0.]
# Time: 25, Inventory: 184, Pipeline: [0, 0, 28, 222, 0]
# [300.]
# Time: 26, Inventory: 86, Pipeline: [0, 28, 222, 0, 300]
# [192.66655]
# Time: 27, Inventory: 0, Pipeline: [28, 222, 0, 300, 192]
# [0.]
# Time: 28, Inventory: 0, Pipeline: [222, 0, 300, 192, 0]
# [0.]
# Time: 29, Inventory: 102, Pipeline: [0, 300, 192, 0, 0]
# [0.]
# Time: 30, Inventory: 0, Pipeline: [300, 192, 0, 0, 0]
# [0.]
# Time: 31, Inventory: 203, Pipeline: [192, 0, 0, 0, 0]
# [0.]
# Time: 32, Inventory: 276, Pipeline: [0, 0, 0, 0, 0]
# [300.]
# Time: 33, Inventory: 172, Pipeline: [0, 0, 0, 0, 300]
# [0.]
# Time: 34, Inventory: 73, Pipeline: [0, 0, 0, 300, 0]
# [240.09042]
# Time: 35, Inventory: 0, Pipeline: [0, 0, 300, 0, 240]
# [64.73718]
# Time: 36, Inventory: 0, Pipeline: [0, 300, 0, 240, 64]
# [53.40525]
# Time: 37, Inventory: 0, Pipeline: [300, 0, 240, 64, 53]
# [0.]
# Time: 38, Inventory: 203, Pipeline: [0, 240, 64, 53, 0]
# [0.]
# Time: 39, Inventory: 108, Pipeline: [240, 64, 53, 0, 0]
# [0.]
# Time: 40, Inventory: 263, Pipeline: [64, 53, 0, 0, 0]
# Total reward: 52242.5
